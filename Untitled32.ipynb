# %%
import pandas as pd
import numpy as np 
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\mani'

# %%
os.chdir("E:\\ai")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('winequality-red.csv' ,sep=';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
fig,ax=plt.subplots(ncols=6,nrows=2,figsize=(20,10))
index=0
ax=ax.flatten()
for col,value in df.items():
    if col!='type':
        sns.boxplot(y=col,data=df,ax=ax[index])
        index +=1

# %%
fig,ax=plt.subplots(ncols=6,nrows=2,figsize=(20,10))
index=0
ax=ax.flatten()
for col,value in df.items():
    if col!='type':
        sns.distplot(value,ax=ax[index])
        index +=1

# %%
df['free sulfur dioxide']=np.log(1+df['free sulfur dioxide'])

# %%
sns.distplot (df['free sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %%
sns.countplot(df['quality'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
corr=df.corr()
plt.figure(figsize=(20,10))
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
x=df.drop(columns=['quality'])
y=df['quality']

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\mani\anaconda3\lib\site-packages (0.8.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\mani\anaconda3\lib\site-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: scikit-learn>=0.24 in c:\users\mani\anaconda3\lib\site-packages (from imbalanced-learn) (0.24.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\mani\anaconda3\lib\site-packages (from imbalanced-learn) (0.17.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\mani\anaconda3\lib\site-packages (from imbalanced-learn) (1.19.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mani\anaconda3\lib\site-packages (from scikit-learn>=0.24->imbalanced-learn) (2.1.0)

# %%
from imblearn.over_sampling import SMOTE

# %%
y.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
sns.countplot(df['quality'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
oversample=SMOTE(k_neighbors=4)
x,y=oversample.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 7    681
# 5    681
# 3    681
# 8    681
# 6    681
# 4    681
# Name: quality, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import cross_val_score,train_test_split

# %%
def classify(model,x,y):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=123)
    model.fit(x_train,y_train)
    print("Accuracy",model.score(x_test,y_test))
    score=cross_val_score(model,x,y,cv=5)
    print("cv Score",np.mean(score))

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
classify(model,x,y)
# Out:
# Accuracy 0.46673189823874756
# cv Score 0.46353317193022353

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()
classify(model,x,y)
# Out:
# Accuracy 0.7808219178082192
# cv Score 0.7325090602209168

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
moel=RandomForestClassifier()
classify(model,x,y)
# Out:
# Accuracy 0.7749510763209393
# cv Score 0.7356887413849345

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model=ExtraTreesClassifier()
classify(model,x,y)
# Out:
# Accuracy 0.8669275929549902
# cv Score 0.8259898908583791

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\mani\anaconda3\lib\site-packages (1.3.3)
# Requirement already satisfied: numpy in c:\users\mani\anaconda3\lib\site-packages (from xgboost) (1.19.2)
# Requirement already satisfied: scipy in c:\users\mani\anaconda3\lib\site-packages (from xgboost) (1.5.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb

# %%
model=xgb.XGBClassifier()
classify(model,x,y)
# Out:
# [01:19:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy 0.8659491193737769
# [01:19:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [01:19:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [01:19:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [01:19:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [01:19:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# cv Score 0.8132675750329937

# %%
pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in c:\users\mani\anaconda3\lib\site-packages (3.1.1)
# Requirement already satisfied: numpy in c:\users\mani\anaconda3\lib\site-packages (from lightgbm) (1.19.2)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\mani\anaconda3\lib\site-packages (from lightgbm) (0.24.1)
# Requirement already satisfied: wheel in c:\users\mani\anaconda3\lib\site-packages (from lightgbm) (0.35.1)
# Requirement already satisfied: scipy in c:\users\mani\anaconda3\lib\site-packages (from lightgbm) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mani\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\mani\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (0.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import lightgbm

# %%
model=lightgbm.LGBMClassifier()
classify(model,x,y)
# Out:
# Accuracy 0.8581213307240705
# cv Score 0.8152253608377003
